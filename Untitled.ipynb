# %%
import pandas as pd

# %%
df_dogs = pd.read_csv('dogs.csv')

# %%
df_dogs.iloc[:, 8:]
# Out:
#      friendliness_to_strangers  watchfulness  ease_of_training  \
# 0                            3             1                 3
# 1                            1             1                 2
# 2                            3             4                 3
# 3                            1             4                 3
# 4                            4             3                 1
# 5                            4             1                 4
# 6                            2             4                 3
# 7                            4             1                 2
# 8                            3             5                 4
# 9                            2             3                 3
# 10                           1             5                 3
# 11                           2             4                 5
# 12                           2             4                 5
# 13                           2             1                 2
# ...

# %%
df_dogs.columns
# Out:
# Index(['name', 'form_and_function', 'energy_level', 'exercise_requirements',
#        'playfulness', 'affection_level', 'friendliness_to_dogs',
#        'friendliness_to_other_pets', 'friendliness_to_strangers',
#        'watchfulness', 'ease_of_training', 'grooming_requirements',
#        'heat_sensitivity', 'vocality', 'type', 'family', 'area_of_origin',
#        'date_of_origin', 'other_names', 'weight_min', 'weight_max',
#        'height_min', 'height_max', 'history', 'temperament', 'upkeep'],
#       dtype='object')

# %%
'name', 'form_and_function', 'energy_level', 'exercise_requirements',
'playfulness', 'affection_level', 'friendliness_to_dogs',
'friendliness_to_other_pets', 'friendliness_to_strangers',
'watchfulness', 'ease_of_training', 'grooming_requirements',
'heat_sensitivity', 'vocality', , 'other_names', 'weight_min', 'weight_max',
'height_min', 'height_max', 'history', 'temperament', 'upkeep'

# %%
One to Many - Foreign Keys: ['category', 'family', 'area_of_origin', 'date_of_origin']
Many to Many - 'Other Names'
# Out:
#   File "<ipython-input-12-6cd1b356224f>", line 1
#     One to Many - Foreign Keys: ['type', 'family', 'area_of_origin', 'date_of_origin']
#          ^
# SyntaxError: invalid syntax
