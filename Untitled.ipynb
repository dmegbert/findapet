# %%
import pandas as pd

# %%
df_dogs = pd.read_csv('dogs.csv')

# %%
df_dogs
# Out:
#                                      name  \
# 0                           Affenpinscher
# 1                            Afghan Hound
# 2                        Airedale Terrier
# 3                                   Akita
# 4                        Alaskan Malamute
# 5                 American Cocker Spaniel
# 6                     American Eskimo Dog
# 7                       American Foxhound
# 8          American Staffordshire Terrier
# 9                  American Water Spaniel
# 10                     Anatolian Shepherd
# 11                  Australian Cattle Dog
# 12                    Australian Shepherd
# 13                     Australian Terrier
# 14                                Basenji
# 15                           Basset Hound
# 16                                 Beagle
# 17                         Bearded Collie
# 18                              Beauceron
# 19                     Bedlington Terrier
# 20            Belgian Shepherd / Malinois
# ...

# %%
df_dogs.columns
# Out:
# Index(['name', 'form_and_function', 'energy_level', 'exercise_requirements',
#        'playfulness', 'affection_level', 'friendliness_to_dogs',
#        'friendliness_to_other_pets', 'friendliness_to_strangers',
#        'watchfulness', 'ease_of_training', 'grooming_requirements',
#        'heat_sensitivity', 'vocality', 'type', 'family', 'area_of_origin',
#        'date_of_origin', 'other_names', 'weight_min', 'weight_max',
#        'height_min', 'height_max', 'history', 'temperament', 'upkeep'],
#       dtype='object')

# %%
'name', 'form_and_function', 'energy_level', 'exercise_requirements',
'playfulness', 'affection_level', 'friendliness_to_dogs',
'friendliness_to_other_pets', 'friendliness_to_strangers',
'watchfulness', 'ease_of_training', 'grooming_requirements',
'heat_sensitivity', 'vocality', , 'other_names', 'weight_min', 'weight_max',
'height_min', 'height_max', 'history', 'temperament', 'upkeep'

# %%
One to Many - Foreign Keys: ['family', 'area_of_origin', 'date_of_origin']
Many to Many - 'Other Names'
# Out:
#   File "<ipython-input-12-6cd1b356224f>", line 1
#     One to Many - Foreign Keys: ['type', 'family', 'area_of_origin', 'date_of_origin']
#          ^
# SyntaxError: invalid syntax

# %%
categories = list(set(df_dogs['type']))

# %%
"'), ('".join(categories)
# Out:
# "Hound'), ('Non-sporting'), ('Terrier'), ('Sporting'), ('Toy'), ('Herding'), ('Working"

# %%
categories = "'Hound', 'Non-sporting', 'Terrier', 'Sporting', 'Toy', 'Herding', 'Working'"

# %%
tables = ['family', 'area_of_origin', 'date_of_origin']

# %%
for table in tables:
    my_list = list(set(df_dogs[table]))
    insert_str = "'), ('".join(my_list)
    insert_str = "('" + insert_str + "')"
    print(insert_str, '\n\n')
# Out:
# ('Livestock dog, Flockguard'), ('Schnauzer, Terrier'), ('Gundog, Spaniel'), ('Gundog, Setter, Pointer, Versatile hunting dog'), ('Terrier, Mastiff'), ('Livestock dog, Mountain dog, Mastiff'), ('Spitz, Northern'), ('Spaniel, Companion'), ('Livestock dog, Sheepdog, Mastiff'), ('Livestock dog, Mastiff'), ('Sighthound, Primitive'), ('Livestock, Herding, Primitive'), ('Oriental'), ('Livestock dog, Mastiff, Water dog'), ('Mastiff'), ('Primative'), ('Unknown'), ('Spitz'), ('Mastiff, Bull'), ('Primative, Hairless'), ('Gundog, Pointer'), ('Pinscher'), ('Likestock dog, Mastiff, Flock guard'), ('Scenthound'), ('Setter, Pointer'), ('Schnauzer'), ('Spitz, Oriental'), ('Primitive'), ('Water dog'), ('Sighthound, Scenthound'), ('Terrier, Mastiff, Bull'), ('Pointer'), ('Sighthound'), ('Gundog, Retriever'), ('Water Dog, Barbichon'), ('Herding'), ('Livestock dog, Mastiff, Bull'), ('Spaniel'), ('Livestock dog, Herding, Schnauzer'), ('Northern'), ('Gundog, Pointer, Versatile hunting dog'), ('Water Dog'),
# ...

# %%
familys = list(set(df_dogs['family']))

# %%
my_family_set = set(["".join(family.split(',')) for family in familys])

# %%
all_fams = [family.split(',') for family in familys]

# %%
fams = sorted(set([item.strip() for sublist in all_fams for item in sublist]))

# %%
fams
# Out:
# ['Barbichon',
#  'Bull',
#  'Companion',
#  'Flock guard',
#  'Flockguard',
#  'Gundog',
#  'Hairless',
#  'Herding',
#  'Likestock dog',
#  'Livestock',
#  'Livestock dog',
#  'Mastiff',
#  'Mountain dog',
#  'Northern',
#  'Oriental',
#  'Pinscher',
#  'Pointer',
#  'Primative',
#  'Primitive',
#  'Retriever',
#  'Scenthound',
#  'Schnauzer',
#  'Setter',
#  'Sheepdog',
#  'Sighthound',
#  'Spaniel',
#  'Spitz',
#  'Terrier',
#  'Unknown',
#  'Versatile hunting dog',
#  'Water Dog',
#  'Water dog']

# %%
insert_str = "'), ('".join(fams)
insert_str = "('" + insert_str + "')"
print(insert_str)
# Out:
# ('Barbichon'), ('Bull'), ('Companion'), ('Flock guard'), ('Flockguard'), ('Gundog'), ('Hairless'), ('Herding'), ('Likestock dog'), ('Livestock'), ('Livestock dog'), ('Mastiff'), ('Mountain dog'), ('Northern'), ('Oriental'), ('Pinscher'), ('Pointer'), ('Primative'), ('Primitive'), ('Retriever'), ('Scenthound'), ('Schnauzer'), ('Setter'), ('Sheepdog'), ('Sighthound'), ('Spaniel'), ('Spitz'), ('Terrier'), ('Unknown'), ('Versatile hunting dog'), ('Water Dog'), ('Water dog')

# %%
names = list(set(df_dogs['other_names']))
my_family_set = set(["".join(family.split(',')) for family in familys])
# Out:
# ['English Bull Terrier',
#  'Deerhound',
#  'Cao de Agua',
#  'Polski Owczarek Nizinny, PON',
#  'Kalef K’naani, Kelev Cana’ani',
#  'Riesenshnauzer',
#  'Iceland Spitz, Iceland Dog, Friaar Dog, Íslenskur Fjárhundur',
#  'Mops, Carlin',
#  'Elkhound, Norsk Elghund',
#  'Piccolo Levrieve Italiani',
#  'Akita Inu, Japanese Akita',
#  'Aberdeen Terrier, Scottie',
#  'Wolf Spitz',
#  'Zwergteckel',
#  'Irish Glen of Imaal Terrier',
#  'English Beagle',
#  'Deutsche Dogge, German Mastiff',
#  'Rothbury Terrier',
#  'Chien de Berger Belge',
#  'Norsk Buhund',
#  'Dhokhi Apso',
#  'Epagneul Nain, Phalene, Continental Toy Spaniel',
#  'American Pit Bull Terrier',
#  'Västgötaspets',
#  'Redbone Hound',
#  'Brushwood Dog, Japanese Small-size Dog',
#  'Groenendael',
#  'Yellow Retriever',
#  'Poltalloch Terrier',
#  'Weimaraner Vorstehund',
#  'Podenco Ibicenco, Ca Eivissenc, Balearic Dog',
#  'Griffon Beige, Friffon Bruxellois, Belgian Griffon',
#  ' ',
#  'Belgian Cattle Dog',
# ...
